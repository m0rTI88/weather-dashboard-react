# %% [markdown]
# <a href="https://colab.research.google.com/github/m0rTI88/weather-dashboard-react/blob/main/ATM_Simulator_Timur_Allamberganov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ATM Simulator
# Author: Timur Allamberganov

# Function to show the ATM menu
def show_menu():
    print("\n=== ATM MENU ===")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

# Function to check current balance
def check_balance(balance):
    print(f"Your current balance is: {balance} UZS")

# Function to deposit money
def deposit(balance):
    amount = float(input("Enter amount to deposit: "))
    if amount > 0:
        balance += amount
        print(f"You have successfully deposited {amount} UZS.")
    else:
        print("Invalid amount. Please enter a positive number.")
    return balance

# Function to withdraw money
def withdraw(balance):
    amount = float(input("Enter amount to withdraw: "))
    if amount <= 0:
        print("Invalid amount. Please enter a positive number.")
    elif amount > balance:
        print("Insufficient funds.")
    else:
        balance -= amount
        print(f"You have successfully withdrawn {amount} UZS.")
    return balance

# Main program
balance = 100000  # initial balance

while True:
    show_menu()
    choice = input("Enter your choice (1-4): ")

    if choice == '1':
        check_balance(balance)
    elif choice == '2':
        balance = deposit(balance)
    elif choice == '3':
        balance = withdraw(balance)
    elif choice == '4':
        print("Thank you for using the ATM!")
        break
    else:
        print("Invalid input! Please enter a number between 1 and 4.")
# Out:
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 1
# Your current balance is: 100000 UZS
#
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 1
# Your current balance is: 100000 UZS
#
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 2
# Enter amount to deposit: 50000
# You have successfully deposited 50000.0 UZS.
#
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 1
# Your current balance is: 150000.0 UZS
#
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 3
# Enter amount to withdraw: 20000
# You have successfully withdrawn 20000.0 UZS.
#
# === ATM MENU ===
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice (1-4): 4
# Thank you for using the ATM!
